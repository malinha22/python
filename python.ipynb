# %% [markdown]
# <a href="https://colab.research.google.com/github/malinha22/python/blob/main/python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Aula 1** ⛵⛰🐇

# %%
ano = "IV"
print(ano, "competição de programação dá Start")
# Out:
# IV competição de programação dá Start

# %% [markdown]
# #**Aula 2**  ⛲⛴⏱

# %%
livro_ficcao = 8
livro_n_ficcao = 10
livro_infantil = 6
pontos_rodrigo = livro_ficcao + livro_n_ficcao + livro_infantil
pontos_ana = 2 * livro_ficcao + 5 * livro_infantil
pontos_totais = pontos_rodrigo + pontos_ana
print(f"Os pontos totais do Rodrigo são {pontos_rodrigo}")
print(f"Os pontos totais de Ana são {pontos_ana}")
print(f"Os pontos totais de Ana e Rodrigo são {pontos_totais}")
# Out:
# Os pontos totais do Rodrigo são 24
# Os pontos totais de Ana são 46
# Os pontos totais de Ana e Rodrigo são 70

# %% [markdown]
# #**Aula 3**  ⏰⚾⛹

# %%
total_de_figurinhas = int(input("Digite o total de figurinhas: "))
numero_de_amigos = int(input("Digite o número de amigos: "))
figurinhas_amigo = total_de_figurinhas // (numero_de_amigos + 2)
figurinhas_joao = 2 * figurinhas_amigo
figurinhas_extras = int(input("Digite o número de figurinhas extras: "))
figurinhas_extras = figurinhas_extras // (numero_de_amigos + 2)
figurinhas_joao2 = figurinhas_extras * 2

print(f"João recebeu {figurinhas_joao} figurinhas")
print(f"João recebeu {figurinhas_joao2} figurinhas extras")
# Out:
# Digite o total de figurinhas: 200
# Digite o número de amigos: 8
# Digite o número de figurinhas extras: 65
# João recebeu 40 figurinhas
# João recebeu 12 figurinhas extras

# %% [markdown]
# #**Aula 4** ⛏ ⛱ ⏳
#
# ##Dia de prova

# %%
P = int(input("Digite a posição da porta P (0 ou 1): "))
R = int(input("Digite a posição da porta R (0 ou 1): "))
if P == 0:
    print("C")
elif R == 1:
    print("A")
else:
    print("B")
# Out:
# Digite a posição da porta P (0 ou 1): 1
# Digite a posição da porta R (0 ou 1): 1
# A

# %% [markdown]
# #**Aula 5 - Cálculo de IMC** 🤐🧟🦯

# %%
peso = float(input("Digite seu peso (em kg): "))
altura = float(input("Digite sua altura (em metros): "))
imc = peso / (altura ** 2)
print(f"\nSeu IMC é: {imc:.2f}")
if imc < 18.5:
    print("Você está abaixo do peso.")
elif 18.5 <= imc < 25:
    print("Você está no peso ideal.")
elif 25 <= imc < 30:
    print("Você está com sobrepeso.")
else:
    print("Você está acima do peso.")
# Out:
# Digite seu peso (em kg): 60
# Digite sua altura (em metros): 1.70
#
# Seu IMC é: 20.76
# Você está no peso ideal.

# %% [markdown]
# #***Aula 6 - tabuada*** 😽🐎🍪

# %%
def tabuada(numero):
    for contador in range(1, 11):  # Gera números de 1 a 10
        print(f"{numero} x {contador} = {numero * contador}")
numero = int(input("Digite um número para ver sua tabuada: "))
tabuada(numero)
# Out:
# Digite um número para ver sua tabuada: 12
# 12 x 1 = 12
# 12 x 2 = 24
# 12 x 3 = 36
# 12 x 4 = 48
# 12 x 5 = 60
# 12 x 6 = 72
# 12 x 7 = 84
# 12 x 8 = 96
# 12 x 9 = 108
# 12 x 10 = 120

# %% [markdown]
# #***Aula 7 - idade*** 🏴📵🐂

# %%
def calcula_idade_maior(idade_monica, idade_filho1, idade_filho2):
  idade_filho3 = idade_monica - idade_filho1 - idade_filho2
  idade_maxima = max(idade_filho1, idade_filho2, idade_filho3)
  return idade_filho3, idade_maxima
resultado = calcula_idade_maior(68, 12, 30)
print(resultado)
# Out:
# (26, 30)

# %% [markdown]
# #***Aula 8*** 🎯🔫📌

# %%
print("Sou seu assistente virtual \n")
nome = input("Digite seu nome: ")
print(f"Olá {nome}, em que posso ajudar?")
resposta = input("Qual assunto você deseja tratar? Matemática, Python ou Javascript: ").lower()
if resposta=="python":
  print("Ótimo, vamos falar sobre Python!")
  print("O Python é uma linguagem de programação de alto nível, interpretada e extremamente versátil, que se destaca pela sua simplicidade e legibilidade do código. Projetada com o objetivo de priorizar a produtividade do desenvolvedor, sua sintaxe limpa e concisa permite que se escreva código complexo com poucas linhas.")
elif resposta=="matemática":
  print("Perfeito, vamos resolver umas questões de matemática!")
  print("A Matemática é a ciência que investiga as quantidades, o espaço, as estruturas e as variações. Longe de ser apenas um conjunto de cálculos escolares, ela se estabelece como a linguagem universal do raciocínio lógico e da precisão.")
elif resposta=="javascript":
  print("Que legal, vamos conversar sobre javascript!")
  print("O JavaScript (JS) é uma linguagem de programação leve e interpretada que começou sua jornada para dar dinamismo e interatividade às páginas web. Originalmente executada apenas no lado do cliente (no navegador), ela evoluiu para se tornar a linguagem fundamental da web moderna.")
else:
  print("Hum, não sei falar sobre esse assunto ")
# Out:
# Sou seu assistente virtual
#
# Digite seu nome: malia
# Olá malia, em que posso ajudar?
# Qual assunto você deseja tratar? Matemática, Python ou Javascript: python
# Ótimo, vamos falar sobre Python!
